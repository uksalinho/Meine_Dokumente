# %% [markdown]
# and => *ilk* **False** ifadeyi döndürür. *Hepsi* **True** ise en son ifadeyi döndürür.

# %% [markdown]
# or => *ilk* **True** ifadeyi döndürür. *Hepsi* **False** ise en son ifadeyi döndürür.

# %%
num1 = int(input("Sayı-1 ..: "))
num2 = int(input("Sayı-2 ..: "))

msj_baslik = "***\tHesap Makinem\t***"
msj_tire = "---------------------------"
print (msj_baslik, "\n", msj_tire)
print ("Sayılar\t..:", num1, "ve", num2)
print("Toplamı\t..:", num1 + num2)
print("Farkı\t..:", num1 - num2)
print("Çarpımı\t..:", num1 * num2)
print("Bölümü\t..:", num1 / num2)
print("Mod(",num1,"%", num2,")..: ", num1%num2, sep="")
print("1.sayının karesi\t..:", pow(num1,2))
print("1.sayının karekökü\t..:", pow(num1,0.5))
import math
x = math.sqrt(num1)  # karekök almak icin 
print("1.sayının karekökü\t..:", x)
# Out:
# ***	Hesap Makinem	***
#  ---------------------------
# Sayılar	..: 5 ve 5
# Toplamı	..: 10
# Farkı	..: 0
# Çarpımı	..: 25
# Bölümü	..: 1.0
# Mod(5%5)..: 0
# 1.sayının karesi	..: 25
# 1.sayının karekökü	..: 2.23606797749979
# 1.sayının karekökü	..: 2.23606797749979

# %%
print(not 0 and "write me")
print([] or "Hello World!")
# Out:
# write me
# Hello World!

# %% [markdown]
# ###The Strength of the String

# %% [markdown]
# ###**Indexing & Slicing Strings**

# %%
city = "Phoenix"

print(city[1:])
print(city[:6])
print(city[::2])
# print(city[1::0]) #adım miktarı(step) 0 olamaz!
print(city[-3:])
print(city[::-1])  # Tersten yazdi
# Out:
# hoenix
# Phoeni
# Ponx
# nix
# xineohP

# %%
animal = "Hippopotamus"

print(animal[1:])
print(animal[:6])
print(animal[::2])
print(animal[1:7:2])
print(animal[-3:])
print(animal[::-1])
# Out:
# ippopotamus
# Hippop
# Hpooau
# ipp
# mus
# sumatopoppiH

# %%
# method-1
dil = "Python"  # y karakterini 'i' ile degistirme
dil = dil[:1] + 'i' + dil[2:]
print(dil)
# Out:
# Pithon

# %%
# method-2
dil = "Python"  # y karakterini 'i' ile degistirme
dil = dil.replace("y","i")
print(dil)
# Out:
# Pithon

# %%
# method-2
city = "Phoenix"
city = city.replace("o", "y")
print(city)
# Out:
# Phyenix

# %%
# method-3
city = "Phoneix"
city2 = list(city)
city2[2] = "y"
print(city2)   # * yokken normal liste formatinda karakter karakter basti
print(*city2)  # * Achtung
# Out:
# ['P', 'h', 'y', 'n', 'e', 'i', 'x']
# P h y n e i x

# %%
# Bir A değişkeninin içeriğini 5 farklı yol ile ekrana yazdırabiliriz.
A = 1453
print("Tarih..:", A)
print("Tarih..: " + str(A))
print("Tarih..: {}".format(A))
print(f"Tarih..: {A}")
print("Tarih..: %d" %A)
# Out:
# Tarih..: 1453
# Tarih..: 1453
# Tarih..: 1453
# Tarih..: 1453
# Tarih..: 1453

# %%
fruit = "Orange"
amount = 4

print("The amount of {} we bought is {} pounds".format(fruit, amount))
# Out:
# The amount of Orange we bought is 4 pounds

# %%
fruit = "Orange"
amount = 4

print(f"The amount of {fruit} we bought is {amount} pounds")  # üstekinin farkli yöntemi
# Out:
# The amount of Orange we bought is 4 pounds

# %%
fruit = "Orange"
amount = 4

print("The amount of {0} we bought is {1} pounds".format(fruit, amount))
# Out:
# The amount of Orange we bought is 4 pounds

# %%
fruit = "Orange"
amount = 4

print("The amount of {1} we bought is {0} pounds".format(fruit, amount))
# Out:
# The amount of 4 we bought is Orange pounds

# %%
fruit = "Orange"
vegetable = 'Tomato'  # printte yok ama önemli degil
amount = 4

print("The amount of {} we bought is {} pounds".format(fruit, amount, vegetable))
# Out:
# The amount of Orange we bought is 4 pounds

# %%
fruit = "Orange"
vegetable = 'Tomato'
amount = 4

print("The amount of {} we bought is {} pounds".format(fruit))  # 2 degisken tanimladim ama 1 tane var hata verdi
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-f9c9b936e744> in <module>()
#       3 amount = 4
#       4
# ----> 5 print("The amount of {} we bought is {} pounds".format(fruit))  # 2 degisken tanimladim ama 1 tane var hata verdi
#
# IndexError: tuple index out of range

# %%
fruit_vegetable_amount = "Orange", 'Tomato', 4, 6, "ali"
print(fruit_vegetable_amount)
# Out:
# ('Orange', 'Tomato', 4, 6, 'ali')

# %%
fruit_vegetable_amount, second_name = "Orange", ('Tomato', 4, "ali")
print(fruit_vegetable_amount, second_name)  # 2. degiskenin tamamini aldi. Cünkü 1. indis 3 elemanli
# Out:
# Orange ('Tomato', 4, 'ali')

# %%
print("{6} {5} {0} {1} {3} {4} {2}".format("a new", "job", "months", "in", 6, "have started", "I will"))
# Out:
# I will have started a new job in 6 months

# %%
print('{state} is the most {adjective} state of the {country}'.format(state="California", country='USA', adjective='crowded'))
# Out:
# California is the most crowded state of the USA

# %%
print('{0} is the most {2} state of the {1}'.format("California", 'USA', 'crowded'))
# Out:
# California is the most crowded state of the USA

# %%
phrase = '{} {} {} {}'.format('circumstances', 'in all', 'generosity', 'wins')
print(phrase)
# Out:
# circumstances in all generosity wins

# %%
condition = 'circumstances'
morality = 'generosity'

phrase = '{} {} {} {}'.format(condition, 'in all', morality, 'wins')
print(phrase)
# Out:
# circumstances in all generosity wins

# %%
phrase = '{2} {0} {1} {3}'.format('circumstances', 'in all', 'generosity', 'wins')
print(phrase)
# Out:
# generosity circumstances in all wins

# %%
sample = f"{2 ** 3}"
print(sample)

sample = "{2 ** 3}"  # Tirnak icinde stringdir
print(sample)

sample = f"2 ** 3"
print(sample)

sample = f"2 ** 3 = {2 ** 3}"
print(sample)

sample = "2 ** 3 = {}".format(2**3)
print(sample)

sample = "2 ** 3 = {0}".format(2**3)
print(sample)
# Out:
# 8
# {2 ** 3}
# 2 ** 3
# 2 ** 3 = 8
# 2 ** 3 = 8
# 2 ** 3 = 8

# %%
_name = "PYTHON LANGUAGE"
print(_name.capitalize())  # ilk harfi büyük yapti
print(_name.title())  # tüm kelimelerin ilk harfini büyük yapti
# Out:
# Python language
# Python Language

# %%
_name = "PYTHON LANGUAGE"
print(len(_name)) # karakter uzunluğu
print(_name.count('A')) # string içerisinde geçen 'A' karakteri sayısı
print(_name.count('AN'))
# Out:
# 15
# 2
# 1

# %%
# Bir metindeki kelime ve harf sayısını bulalım
words = "Bir metindeki kelime ve harf sayısını bulalım."
print(len(words))
bosluk_sayisi = words.count(' ')  # space karakterlerini say
nokta_sayisi = words.count('.')
harf_sayisi = len(words) - bosluk_sayisi - nokta_sayisi
print("Harf Sayısı..:", harf_sayisi)
print("Kelime Sayısı..:", bosluk_sayisi+1)
# Out:
# 46
# Harf Sayısı..: 39
# Kelime Sayısı..: 7

# %%
name = 'Joseph'
job = "teachers"
domain = 'Data Science'

message = (
    f"Hi {name}. "
    f'You are one of the {job} '
    f'in the {domain} section...'
)

print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section...

# %%
name = 'Joseph'
job = "teachers"
domain = 'Data Science'
# Satiri bölmek icin ama yine yan yana basar. Yani 73 karakterden fazla olsaydi kullanisli
message = f"Hi {name}."\  
    f'You are one of the {job}'\ 
    f'in the {domain} section...'

print(message)
# Out:
#   Input In [8]
#     message = f"Hi {name}."\
#                             ^
# SyntaxError: unexpected character after line continuation character

# %%
name = 'Joseph'
job = "teachers"
domain = 'Data Science'
#  \ Satiri bölmek icin ama yine yan yana basar. Yani 73 karakterden fazla olsaydi kullanisli
message = f"Hi {name}. "\
    f'You are one of the {job} '\
    f'in the {domain} section...'

print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section...

# %%
name = "Susan"
age = "young"
gender = "lady"
school = "CLRWY IT university"

output = (
	f"{name} is a {age} "
	f"{gender} and she is a student "
	f"at the {school}."
)
print(output)
# Out:
# Susan is a young lady and she is a student at the CLRWY IT university.

# %%
str_one = 'upper'
str_two = 3 * 'upper'
str_comb = str_one * 3
print(str_two)
print(str_comb)
print(str_one*3)
# Out:
# upperupperupper
# upperupperupper
# upperupperupper

# %%
str_one = 'upper'
str_two = 3 * 'upper'
str_comb = str_one * 3
print(str_two)
print(str_comb)
print(* str_one)  # * isareti String karakterleri ayirmak icin kullanildi. [], {} kurtulmak icin de * kullaniliyor.
# Out:
# upperupperupper
# upperupperupper
# u p p e r

# %%
str_one = "Clarusway"
print(str_one.startswith("C"))  # C ile mi basladi sorusu

str_one = "Clarusway"
print(str_one.endswith("C"))  # C ile mi bitti sorusu
# Out:
# True
# False

# %%
str_one = "Clarusway"
print(str_one.find("a"))  # string icerisinde arama yapar varsa ilk buldugunun indis no'yu döner  

str_one = "Clarusway"
print(str_one.find("a", 3, len(str_one)))  # 3. indisden itibaren sona kadar "a" varsa kacinci indisde
# Out:
# 2
# 7

# %%
_name = "PYTHON LANGUAGE"
print(_name.find('A')) # 'A' karakterinin pozisyonu/indisi
print(_name.index('A')) # 'A' karakterinin pozisyonu/indisi
# Out:
# 8
# 8

# %%
_name = "PYTHON LANGUAGE"
print(_name.find('e'))  # Olmayani -1 döndürdü
print(_name.index('e'))  # Olmayana hata verdi
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\uksal\Desktop\Meine_Dokumente\Tag_4.ipynb Cell 41' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/uksal/Desktop/Meine_Dokumente/Tag_4.ipynb#ch0000040?line=0'>1</a> _name = "PYTHON LANGUAGE"
#       <a href='vscode-notebook-cell:/c%3A/Users/uksal/Desktop/Meine_Dokumente/Tag_4.ipynb#ch0000040?line=1'>2</a> print(_name.find('e'))  # Olmayani -1 döndürdü
# ----> <a href='vscode-notebook-cell:/c%3A/Users/uksal/Desktop/Meine_Dokumente/Tag_4.ipynb#ch0000040?line=2'>3</a> print(_name.index('e'))
#
# ValueError: substring not found

# %%
_name = "pYTHON lANGUAGE"
print(_name.swapcase())  # Kücük büyük harf dönüsümü yapar
# Out:
# Python Language

# %%
email = "clarusway@clarusway.com is my e-mail address"
print(email.startswith("@", 9))  # 9 . karakter @ ile mi basliyor?
print(email.endswith("-", 10, 32))  # 10. - 32. karakter arasi - ile mi bitiyor?
# Out:
# True
# True
