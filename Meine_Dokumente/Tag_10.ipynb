# %% [markdown]
# **Control Flow Statements**
#
#
# 1.   Conditionals
# 2.   Loops

# %% [markdown]
# Tek bir kosul varsa if kullanilir.
#
# ---
#
#
# The basic structure of an **if** statement is:
#
# ---
#
#
# if condition:
#
#
# > body

# %%
a = 1
if a:  # == True demek aslinda. a=1 yerine 0 yazsam True olmadigi icin hic bir sey dönmez ve hata da vermez ama program calisir 
    print("a..", a)  # True ifade
# Out:
# a.. 1

# %%
a = True
if a: 
    print("a..", a)  # True ifade
# Out:
# a.. True

# %%
a = "-"
if a: 
    print("a..", a)  # True ifade
# Out:
# a.. -

# %%
a = None  # 0, 0.0, False, None, içi boş string False'dur
if a:     # Bunlar disindakiler True olur
    print("a..", a)  # Kosulu saglamadi ve bloga girmedi. 4. satirdan devam eder ama yok

# %%
#Girintilerin eşit seviyede olması lazım!!!
if True:  # True sonucunu üreten bir değerse
          # blok çalışacak
    print("it is True")
# Out:
# it is True

# %%
#hamburger örneği
minced = True
bread = True
lettuce = False
pepper = True
grocer = True
hamburger = (minced and bread and grocer) and (lettuce or pepper)
if hamburger==True:
    print("Afiyet Olsun!")
# Out:
# Afiyet Olsun!

# %%
#hamburger örneği
minced = True
bread = False
lettuce = False
pepper = True
grocer = True
hamburger = (minced and bread and grocer) and (lettuce or pepper)
if hamburger:   ## Ayrıca üstteki gibi '==True' sorgusuna gerek yok
    print("Afiyet Olsun!")
# Gerekli olan malzemeler yoksa sonuc vermez, hata da vermez. Sonuc dogru olsa calisirdi False olunca devam etmedi

# %%
#takdir ve onur belgesi-1
ort = int(input("Ortalamayı giriniz..:"))
turkce = int(input("Türkçe Notu..:"))
print(ort)
print(turkce)
if ort >= 85:
    if turkce > 70:
        print("takdir belgesi alabilir")
# sadece if var. yeterli puanlardan az olunca sonuc vermez, hata da vermez
# Out:
# 85
# 85
# takdir belgesi alabilir

# %%
#takdir ve onur belgesi-2
ort = int(input("Ortalamayı giriniz..:"))
turkce = int(input("Türkçe Nou..:"))
print(ort)
print(turkce)
if ort >= 85 and  turkce > 70:
        print("takdir belgesi alabilir")
# Out:
# 90
# 90
# takdir belgesi alabilir

# %%
#takdir ve onur belgesi-3
takdir = False # garantiye almamız lazım. Bunun icin bayrak degeri atadik
ort = int(input("Ortalamayı giriniz..:"))
turkce = int(input("Türkçe Nou..:"))
print(ort)
print(turkce)
if ort >= 85 and turkce >= 70:
    takdir = True  # flag (durum bayrağı)
 # en üstte garantiye almazsam 85 ve 50 bile girsem yine de alir diye basardi
if takdir:
    print("Takdir Belgesi alabilir!")
else:
    print("Takdir belgesi alamaz!!!")
# Out:
# 50
# 50
# Takdir belgesi alamaz!!!

# %%
#takdir ve onur belgesi-4
ort = int(input("Ortalamayı giriniz..:"))
turkce = int(input("Türkçe Nou..:"))
print(ort)
print(turkce)
if ort>=85 and turkce>=70:         # üstteki bayrak atamasini yapmadim
    print("Takdir Belgesi alabilir!")
else:
    print("Takdir belgesi alamaz!!!")
# Out:
# 90
# 69
# Takdir belgesi alamaz!!!

# %% [markdown]
# Comparison Operators
# *   != NOT EQUAL
# *   == EQUAL
# *   < LESS THAN
# *   GREATER THAN >
# *   GREATER THAN OR EQUAL >=
# *   <= LESS THAN OR EQUAL

# %%
empty_seat = 14
if empty_seat > 3:
	print('there is still seat to sit')
# Out:
# there is still seat to sit

# %%
# := operatörü ne işe yarar?
# Koşul ifadelerinde değer atamak için
# parantez içerisinde yazılır...
if (empty_seat:=14 > 3):
	print('there is still seat to sit')
 # yeni bir özellik. colabda calismadi
# Out:
# there is still seat to sit

# %%
(empty_seat := 14)  # üsteki yeni özelligi farkli yazdi
if empty_seat > 3:
	print('there is still seat to sit')
# Out:
# there is still seat to sit

# %%
empty_seat := 14  # := özelligi parantez icinde olmali !!!
if empty_seat > 3:
	print('there is still seat to sit')
# Out:
#   Input In [11]
#     empty_seat := 14  # := özelligi parantez icinde olmali
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# SET --> KÜMELER

# %%
set1 = set('TWELVE PLUS ONE')  # set ayni elemanlari tekrar yazmaz
print(set1)
set2 = set('ELEVEN PLUS TWO')  # set ayni elemanlari tekrar yazmaz
print(set2)
if (set1==set2):
    print("We are the same!")  # yani set1 ve set 2 ayni
# Out:
# {'E', 'O', 'U', 'V', 'N', 'L', ' ', 'W', 'P', 'S', 'T'}
# {'E', 'O', 'U', 'V', 'N', 'T', 'L', ' ', 'W', 'S', 'P'}
# We are the same!

# %%
set1 = set('TWELVE PLUS ONE')
set2 = set('ELEVEN PLUS ONE')
if (set1==set2):  # dogruysa basar degilse hic bir sey yapmaz cünkü else yok
    print("We are the same!")

# %%
convert = input("Enter Yes or No :") #
print(convert)
if (convert=="Yes"):                   # yine sadece if var. no yazinca bir sey olmuyor. Yes de ayni olmali, hepsi kücük harf olmaz
    print("You entered", bool(convert))
# Out:
# Yes
# You entered True

# %%
convert = input("Enter Yes or No :").title() == "Yes"  
print(convert) 
print("You entered", convert)  # kücük harf ile girersem bile title bas harfi büyük yapar
# Out:
# True
# You entered True

# %%
convert = input("Enter Yes or No :").title().strip() == "Yes" 
print("You entered", convert)  # kücük harf ve boslukla yazsam da title ve strip düzeltir
# Out:
# Enter Yes or No : yes
# You entered True

# %%
convert = input("Enter Yes or No :") 
if (convert.title().strip()=="Yes"):
    print("You entered", bool(convert))
# Out:
# Enter Yes or No :yes
# You entered True

# %% [markdown]
# **if** kosul dogruysa calisiyordu ama yanlissa bir sey yapmiyordu. Kosul yanlissa baska bir islem yap demek icin **else** kullanilir.

# %%
number = 5
if number <= 3:
	print('Number is smaller than or equal to 3')
else:
	print('Number is bigger than 3')
# Out:
# Number is bigger than 3

# %%
if (number := 5) <= 3:  # colabda calismayan yeni özellik ile yukardakini yazdim
	print('Number is smaller than or equal to 3')
else:
	print('Number is bigger than 3')
# Out:
# Number is bigger than 3

# %%
num = int(input("You entered number..:"))
if num % 2 == 0:  # cift sayiysa even
    print(f"{num} is even.")
else:
    print(f"{num} is odd.")  # degilse odd
# Out:
# 22 is even.

# %%
num = int(input("You entered number..:"))
print(num, num % 2 == 0 and "even" or "odd")  # cift sayi mi degil mi
# Out:
# 11 odd

# %%
## 1. Positive-Negatif-Zero?
num = float(input("You entered number..:"))
if num>0:
    print("positive")
else:               # 0 asagida elif seklinde yazdim
    if num<0:
        print("negative")
    else:
        print("zero")
# Out:
# You entered number..:0
# zero

# %%
## 2. Positive-Negatif-Zero?
num = float(input("You entered number..:"))
default = "zero"  # durum değişkeni (o anki durumu gösteren bir bayrak)
if num>0:         # poz. veya neg. disinda sifir da olabilir
    default="positive"
if num<0:
    default="negative"

print(default)
# Out:
# You entered number..:0
# zero

# %% [markdown]
# else if yerine elif

# %%
## 3. Positive-Negatif-Zero?
num = float(input("You entered number..:"))
print(num)
if num>0:
    print("positive")
elif num<0:
    print("negative")
else:
    print("zero")
# Out:
# 0.0
# zero

# %%
num1 = float(input("You entered number-1..:"))
num2 = float(input("You entered number-2..:"))
if num1>num2:
    larg = num1
else:          # hangisi büyük
    larg = num2

print(f"{larg} is larger.")
# Out:
# You entered number-1..:5
# You entered number-2..:12
# 12.0 is larger.

# %%
num1 = float(input("You entered number-1..:"))
num2 = float(input("You entered number-2..:"))
larg = max(num1,num2)  # üstekini döngüye sokmadan daha kolayi
print(f"{larg} is larger.")
# Out:
# You entered number-1..:28
# You entered number-2..:36
# 36.0 is larger.

# %%
audience = 'baby'  # baby hicbir katogoride yok

if audience == 'kid':
	print('it is free to go to cinema')
elif audience == 'teen':
	print('discounted price!')
elif audience == 'adult':
	print('normal price')
else:
	print('No such audience, stay at your home!')
# Out:
# No such audience, stay at your home!

# %%
audience = 'adult'

if audience == 'kid':
	print('it is free to go to cinema')
elif audience == 'teen':
	print('discounted price!')
elif audience == 'adult':
	print('normal price')
else:
	print('No such audience, stay at your home!')
# Out:
# normal price

# %%
##a. 3 sayı içerisinden en büyüğü
num1 = float(input("You entered number-1..:"))
num2 = float(input("You entered number-2..:"))
num3 = float(input("You entered number-3..:"))
if num1 >= num2 and num1 >= num3:
    larg = num1
elif num2 >= num1 and num2 >= num3:
    larg = num2
else:
    larg = num3
    
print(f"{larg} is larger.")
# Out:
# You entered number-1..:5
# You entered number-2..:8
# You entered number-3..:9
# 9.0 is larger.

# %%
##b. 3 sayı içerisinden en büyüğü
num1 = float(input("You entered number-1..:"))
num2 = float(input("You entered number-2..:"))
num3 = float(input("You entered number-3..:"))
larg = max(num3, max(num1,num2))
    
print(f"{larg} is larger.")
# Out:
# You entered number-1..:30
# You entered number-2..:1
# You entered number-3..:2
# 30.0 is larger.

# %%
##c. 3 sayı içerisinden en büyüğü
num1 = float(input("You entered number-1..:"))
num2 = float(input("You entered number-2..:"))
num3 = float(input("You entered number-3..:"))
larg = num1 # ön kabul(birini en büyük kabul ediyoruz)
            # karsilastirma sayisi azaldi67
            
if num2 >= larg:
    larg = num2
if num3 >= larg:
    larg = num3
    
print(f"{larg} is larger.")
# Out:
# You entered number-1..:2
# You entered number-2..:5
# You entered number-3..:1
# 5.0 is larger.

# %%
##a. Bilet indirimi
seyirci_grup = 'kid', 'teen', 'adult'
seyirci = "kid"
if seyirci in seyirci_grup:
    if seyirci == 'kid':
        print('it is free')
    elif seyirci == 'teen':
        print('%50 indirimli bilet')
    else:
        print('normal bilet')
else:
    print("evinde kal!")            # hatali!!! degil aslinda. 3. satiri alttaki gibi input ile yapsam calisiyor
# Out:
# it is free

# %%
##b. Bilet indirimi
seyirci_grup = 'kid', 'teen', 'adult'
seyirci = input('yaş durumunuz..:')
if seyirci in seyirci_grup:
    if seyirci == 'kid':
        print('it is free')
    elif seyirci == 'teen':
        print('%50 indirimli bilet')
    else:
        print('normal bilet')
else:
    if seyirci == 'old':  # elif şeklinde birleştirilebilir...
        print('it is free')
    else:
        print("evinde kal!")  # 3 durum disinda bir sey yazilirsa
# Out:
# evinde kal!

# %%
##c. Bilet indirimi
seyirci_grup = 'kid', 'teen', 'adult'
seyirci = input('yaş durumunuz..:')
if seyirci in seyirci_grup:
    if seyirci == 'kid':
        print('it is free')
    elif seyirci == 'teen':
        print('%50 indirimli bilet')
    else:
        print('normal bilet')
else:
    seyirci = input('yaş durumunuz..:') # elif olamaz! else ile if arasinda islem var
    if seyirci == 'old':
        print('it is free')
    else:
        print("evinde kal!")
# Out:
# yaş durumunuz..:teen
# %50 indirimli bilet

# %%
##a. Harfli not sistemi
ders_notu = int(input("başarı notununu gir..: "))
if ders_notu>=95 and ders_notu<=100:
    skor = "A+"
elif ders_notu>=90 and ders_notu<95:
    skor = "A"
elif ders_notu>=85 and ders_notu<90:
    skor = "B+"
elif ders_notu>=80 and ders_notu<85:
    skor = "B"
else:
    skor = "B-"
print("Harfli Notunuz..: ", skor)
# Out:
# Harfli Notunuz..:  B+

# %%
##b. Harfli not sistemi
ders_notu = int(input("başarı notununu gir..: "))
if ders_notu>=95:      # yukardakilerin and kisimlarini sildik
    skor = "A+"
elif ders_notu>=90:
    skor = "A"
elif ders_notu>=85:
    skor = "B+"
elif ders_notu>=80:
    skor = "B"
else:
    skor = "B-"
print("Harfli Notunuz..: ", skor)
# Out:
# başarı notununu gir..: 90
# Harfli Notunuz..:  A

# %%
##c. Harfli not sistemi
ders_notu = int(input("başarı notununu gir..: "))
if ders_notu >= 90:
    if ders_notu >= 95:
        skor = "A+"
    else:
        skor = "A"
elif ders_notu >= 80:
    if ders_notu >= 85:
        skor = "B+"
    else:
        skor = "B"

else:
    skor = "B-"
print("Harfli Notunuz..: ", skor)
# Out:
# başarı notununu gir..: 99
# Harfli Notunuz..:  A+

# %%
##Sadece 3.10 ve üzeri için geçerli
##d. Harfli not sistemi
ders_notu = int(input("başarı notununu gir..: "))
skor = "B-"
match ders_notu:
    case 95|96|97|98|99|100:
        skor = "A+"
    case 90|91|92|93|94:
        skor = "A"
    case 85|86|87|88|89:
        skor = "B+"
    case 80|81|82|83|84:
        skor = "B"

print("Harfli Notunuz..: ", skor)
# Out:
# Harfli Notunuz..:  B+

# %%
##d. harfli not sistemi
ders_notu = int(input("başarı notununu gir..: "))
if 95<=ders_notu<=100:  # diger dillerde ayri ayri yazilmali
    skor = "A+"
elif 90<=ders_notu<95:
    skor = "A"
elif 85<=ders_notu<90:
    skor = "B+"
elif 80<=ders_notu<85:
    skor = "B"
else:
    skor = "B-"
print("Harfli Notunuz..: ", skor)
# Out:
# başarı notununu gir..: 87
# Harfli Notunuz..:  B+

# %%
x = 3
if 2<=x<6:
    print(x)
else:
    print(x**2)
# Out:
# 3

# %%
#basit hesap makinesi
print("*****My Calculator*****\n[+] Toplama\n[-] Çıkarma\n[*] Çarpma")
print("***********************")
a = 5
b = 3
operator = input("Hangi işlemi yapmak istiyorsunuz?")
if operator =='+':
    islem = a + b
elif operator =='-':
    islem = a - b
elif operator == '*':
    islem = a * b
else:
    print("hatalı operatör")

print(f"Sonuç={islem}")
# Out:
# *****My Calculator*****
# [+] Toplama
# [-] Çıkarma
# [*] Çarpma
# ***********************
# Sonuç=15
