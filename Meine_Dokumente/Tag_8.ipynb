# %%
"Hatırlama: Python Tuples"
a = (1)  ## type: int cünkü parantez icinde , yok ve tek bir eleman var
a = (1,) ## type: tuple cünkü parantez olsa da olmasa da , ile ayrilmis elemanlar var
b = 1,2,3  ## type: tuple cünkü parantezsiz olarak sadece degerler var
c = tuple([1,2,3,4]) ## type: tuple cünkü en basta tuple dedim. 
d = tuple('a')  ## type: tuple bunlar immutable yani dogrudan degistirme yapamam
print(b, c, d, sep="\n")

print(dir(tuple))   ## #tuple methods: 'count', 'index'
tuples = (1, 2, 'hi', 3)
print(tuples.index('hi'))  ## 2 (index of 'hi') indis no verir
print(tuples.count('hi'))  ## 1 (count of 'hi') hi ifadesi kac kere geciyoru verir

print(tuples[1])    ## 1 (accessing a single item) tuple'lara böyle erisiriz
# tuples[2] = 'bye' ## NO, tuples cannot be changed. Tuple'a dogrudan atama yapamam
# del tuples[2]     ## NO, tuples cannot be changed. ve yine dogrudan silemem

tuples = (1, 2, 'bye', 3 )  ## this works because new tuple
print(tuples)
a,b,c,d = tuples    ## unpacking
print(c)            ## 'bye'

tuples1 = (1,2,9,4,5,6,7,0)
print(len(tuples1)) ## 8 uzunluk
print(max(tuples1)) ## 9 en büyük
print(min(tuples1)) ## 0 en kücük
print(sum(tuples1)) ## 34 (sum of items) toplam
# Out:
# (1, 2, 3)
# (1, 2, 3, 4)
# ('a',)
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']
# 2
# 1
# 2
# (1, 2, 'bye', 3)
# bye
# 8
# 9
# 0
# 34

# %%
# Hangi fonksiyonlari var?
print(dir(list))
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
even_no = (0, 2, 4)
print(even_no[0])
print(even_no[1])
print(even_no[2])
print(even_no[3])  # Olmayan degere ulasmaya calisinca hata verir
# Out:
# 0
# 2
# 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-b086b4c961e3> in <module>()
#       3 print(even_no[1])
#       4 print(even_no[2])
# ----> 5 print(even_no[3])  # Olmayan degere ulasmaya calisinca hata verir
#
# IndexError: tuple index out of range

# %%
"""
Let’s access, select and print the string 'six” from the following tuple. 👇
"""
mix_tuple = ('11', 11, [2, 'two', ('six', 6)], (5, 'fair'))
print(mix_tuple[2][2][0])
# Out:
# six

# %%
""" What is the output ? 👇"""
mix_tuple = ('11', 11, [2, 'two', ('six', 6)], (5, 'fair'))
str_six = mix_tuple[2][1:3]
print(str_six, type(str_six), sep='\n')  # tuple icinde liste
print(type(mix_tuple))  # parantez icinde birden fazla eleman var
# Out:
# ['two', ('six', 6)]
# <class 'list'>
# <class 'tuple'>

# %%
mix_tuple = ('11', 11, [2, 'two', ('six', 6)], (5, 'fair'))
option_1 = mix_tuple[3][1]
option_2 = mix_tuple[-1][1]

print(option_1, option_2, sep='\n')
print(type(option_1))
# Out:
# fair
# fair
# <class 'str'>

# %%
# enumerate: verileri numaralandırmak amacıyla kullanılabilir. 
t = (5, 7, 9)
print(list(enumerate(t, start=1)))  # numaralandirma 1'den baslasin dedim
# Out:
# [(1, 5), (2, 7), (3, 9)]

# %%
days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday")
print(list(enumerate(days)))  # baslangic degeri vermedigim icin 0'dan basladi
days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday")
print(list(enumerate(days, start=1)))  # list olarak istedim ve [] ile verdi
days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday")
print(tuple(enumerate(days, start=1)))  # tuple olarak istedim ve () ile verdi
# Out:
# [(0, 'Monday'), (1, 'Tuesday'), (2, 'Wednesday'), (3, 'Thursday'), (4, 'Friday'), (5, 'Saturday'), (6, 'Sunday')]
# [(1, 'Monday'), (2, 'Tuesday'), (3, 'Wednesday'), (4, 'Thursday'), (5, 'Friday'), (6, 'Saturday'), (7, 'Sunday')]
# ((1, 'Monday'), (2, 'Tuesday'), (3, 'Wednesday'), (4, 'Thursday'), (5, 'Friday'), (6, 'Saturday'), (7, 'Sunday'))

# %% [markdown]
# # **Sözlük**
# Hem degisken ifadesi hem de degerler tirnak icine yazilir yani key ve value! Parantez olarak {} kullanilir. {'key'='value'} buna item denir.

# %% [markdown]
# Sadece {} yazilabilir ya da dict() döngüsüne alinarak sözlük yapisi olusturulur. dict sarmalina alininca key icin "" kalkar. Dogrudan degistirme, ekleme yapilabilir. Icinde farkli veri tipleri barindirabilir.

# %%
grocer1 = {'fruit':'apple', 'drink':'water'} 
grocer2 = dict(fruit='apple', drink='water')  ## Eşdeğeri
print(grocer1, grocer2, sep='\n')
# Out:
# {'fruit': 'apple', 'drink': 'water'}
# {'fruit': 'apple', 'drink': 'water'}

# %%
"""zip function: Her tipten koleksiyon verilerini birleştirerek,
bir iterasyon yapılabilecek liste, demet veya sözlük yapısı oluşturmada kullanılır.

Program-1: İki farklı listeyi biri anahtar (key), diğeri değeri (value) olacak
şekilde sözlük yapısına dönüştürmek için zip() fonksiyonu kullanılabilir.
"""
ad = ['one','two','three','four','five']
no = [1, 2, 3, 4, 5 ]
szlk = dict(zip (ad,no))
liste = list(zip(ad,no))
print("Sözlük: ", szlk)  # parantez {}
print("Liste: ", liste)  # parantez []
print(zip(ad,no))  # bir koleksiyon tipine dönüstürmeli
# Out:
# Sözlük:  {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5}
# Liste:  [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]
# ...

# %%
sozluk = {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5}
print(sozluk)
sozluk = {1 : 'one', 2 :'two', 3 : 'three', 4 : 'four', 5 : 'five'}
print(sozluk)
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5}
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}

# %%
sozluk = {one: 1, two: 2, three: 3, four: 4, five: 5}
print(sozluk)  # isimlendirme hatasi verdi. degisken tanimlanmadi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f1ebef178c10> in <module>()
# ----> 1 sozluk = {one: 1, two: 2, three: 3, four: 4, five: 5}
#       2 print(sozluk)  # isimlendirme hatasi verdi. degisken tanimlanmadi
#
# NameError: name 'one' is not defined

# %%
"""
Program-2: İki listenin elemanlarını toplayan programı
map() ve zip() fonksiyonları ile kodlayalım.
"""
t = list(map(sum, zip([1, 2, 3], [4, 5, 6])))  # list tipiyle yazdirdim
print (t)
t = tuple(map(sum, zip([1, 2, 3], [4, 5, 6])))  # tuple tipiyle yazdirdim
print (t)

# %%
state_capitals = {'Arkansas':'Little Rock',
			'Colorado':'Denver',
			'California':'Sacramento',
			'Georgia':'Atlanta',
      'Georgia':'Richmond'  # Iki kere Georgia var son atanani alir.
			}
print(state_capitals)
# Out:
# {'Arkansas': 'Little Rock', 'Colorado': 'Denver', 'California': 'Sacramento', 'Georgia': 'Richmond'}

# %%
state_capitals = {'Arkansas':'Little Rock',
			'Colorado':'Denver',
			'California':'Sacramento',
			'Georgia':'Atlanta'
			}                            # indis yok key var
print(state_capitals['Colorado'])  # accessing method
# Out:
# Denver

# %%
state_capitals = {'Arkansas':'Little Rock',
			'Colorado':'Denver',
			'California':'Sacramento',
			'Georgia':'Atlanta'
			}
state_capitals['Virginia'] = 'Richmond'  # liste sonuna yeni bir item eklendi
print(state_capitals)
# Out:
# {'Arkansas': 'Little Rock', 'Colorado': 'Denver', 'California': 'Sacramento', 'Georgia': 'Atlanta', 'Virginia': 'Richmond'}

# %%
state_capitals = {'Arkansas':'Little Rock',
			'Colorado':'Denver',
			'California':'Sacramento',
			'Georgia':'Atlanta'
			}
state_capitals['Colorado'] = 'Ottowa'  #değiştirme
print(state_capitals)
# Out:
# {'Arkansas': 'Little Rock', 'Colorado': 'Ottowa', 'California': 'Sacramento', 'Georgia': 'Atlanta'}

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha'
         }
print(family)

family = dict(name1 = 'Joseph', name2 = 'Bella', name3 = 'Aisha')
print(family)  # dickt sarmalinda
# Out:
# {'name1': 'Joseph', 'name2': 'Bella', 'name3': 'Aisha'}
# {'name1': 'Joseph', 'name2': 'Bella', 'name3': 'Aisha'}

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha',
          'name4': 'Tom'     # Direkt yeni bir value yazarak ekledim
         }
print(family)
# Out:
# {'name1': 'Joseph', 'name2': 'Bella', 'name3': 'Aisha', 'name4': 'Tom'}

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha'
         }
family['name4'] = 'Tom'  # Yeni bir value ekledim
print(family)
# Out:
# {'name1': 'Joseph', 'name2': 'Bella', 'name3': 'Aisha', 'name4': 'Tom'}

# %%
family = dict(name1= 'Joseph', name2= 'Bella', name3= 'Aisha')
family['name4'] = 'Tom'  # dickt sarmalinda da ayni sekilde ekleme yaptim
print(family)
# Out:
# {'name1': 'Joseph', 'name2': 'Bella', 'name3': 'Aisha', 'name4': 'Tom'}

# %%
dict_by_dict = dict(animal='dog', planet='neptun', number=40, pi=3.14, is_good=True)
print(dict_by_dict)  # Sözlükte farkli veri tipleri olabilir. Hepsini tirnak icine alip yazdirir.
# Out:
# {'animal': 'dog', 'planet': 'neptun', 'number': 40, 'pi': 3.14, 'is_good': True}

# %%
dict_by_dict = {'animal':'dog',
			'planet': 'Neptun',
			'number': 40,
			'pi': 3.14,
			'is_good': True}

print(dict_by_dict.items(), '\n')  # key ve value basar
print(dict_by_dict.keys(), '\n')  # key basar
print(dict_by_dict.values())  # value basar
# Out:
# dict_items([('animal', 'dog'), ('planet', 'Neptun'), ('number', 40), ('pi', 3.14), ('is_good', True)])
#
# dict_keys(['animal', 'planet', 'number', 'pi', 'is_good'])
#
# dict_values(['dog', 'Neptun', 40, 3.14, True])

# %%
dict_by_dict = {'animal':'dog',
			'planet': 'Neptun',
			'number': 40,
			'pi':3.14,
			'is_good': True}

print(dict_by_dict.values(), sep='\n')  # Liste olarak([]) yazdirdigi icin \n olsa bile alt alta yazmadi
# Out:
# dict_values(['dog', 'Neptun', 40, 3.14, True])

# %%
dict_by_dict = {'animal':'dog',
			'planet': 'Neptun',
			'number': 40,
			'pi':3.14,
			'is_good': True}

print(*dict_by_dict.values(), sep='\n')  # * koyarak [] yok saydi ve alt alta basti
# Out:
# dog
# Neptun
# 40
# 3.14
# True

# %%
dict_by_dict = {'animal':'dog',
			'planet': 'Neptun',
			'number': 40,
			'pi':3.14,
			'is_good': True}

print(list(dict_by_dict.values()))  # listeye dönusturdu
# Out:
# ['dog', 'Neptun', 40, 3.14, True]

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha'
         }
family['name4'] = 'Tom'

print(list(family.items()))  # itemsleri liste olarak basti
print(tuple(family.keys()))  # keysleri tuple olarak basti
print(*family.values())  # valuesleri * ile hem ()/[]siz hem de ""siz basti
# Out:
# [('name1', 'Joseph'), ('name2', 'Bella'), ('name3', 'Aisha'), ('name4', 'Tom')]
# ('name1', 'name2', 'name3', 'name4')
# Joseph Bella Aisha Tom

# %%
dict_by_dict = {'animal':'dog',
			'planet': 'Neptun',
			'number': 40,
			'pi':3.14,
			'is_good': True}

dict_by_dict.update({'is_bad':False})  # Güncelleme metodu ile en sona ekledi
print(dict_by_dict)
# Out:
# {'animal': 'dog', 'planet': 'Neptun', 'number': 40, 'pi': 3.14, 'is_good': True, 'is_bad': False}

# %%
d1 = {1:'bir', 2:'iki', 3:'üç'}
d2 = {1:'one', 2:'two', 3:'three'}
d1.update(d2)  # d1'i d2 ile update etti
print(d1)
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d1 = {1:'bir', 2:'iki', 3:'üç'}
d2 = {1:'one', 2:'two', 3:'three'}
d1.update(d2)
print(*d1)  # sadece key'leri verdi cünkü default olan key
# Out:
# 1 2 3

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha',
          'name4': 'Tom'
         }
del family['name2']  # silme komutu del
del family['name1']
print(family)
# Out:
# {'name3': 'Aisha', 'name4': 'Tom'}

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha',
          'name4': 'Tom'
         }
del family['name2'], family['name1']
print(family)
# Out:
# {'name3': 'Aisha', 'name4': 'Tom'}

# %%
del family['name2', 'name1']  # ayrı ayrı yazılması gerekir

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha',
          'name4': 'Tom'
         }
# del ile aynı satırda birden fazla değer nasıl silinir?
family = list(family.items())  ## listeye dönüştü
del family[0:2]                ## dilimleme yapıldı
print(dict(family))
# Out:
# {'name3': 'Aisha', 'name4': 'Tom'}

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha',
          'name4': 'Tom'
         }
family.clear()  # tüm sözlük içeriğini siler
print(family)  # boş sözlük
# Out:
# {}

# %% [markdown]
# *clear* **metot** => nesne.*clear* yazdik
# , *del* **komut** => *del* nesne yazdik

# %%
family = {'name1': 'Joseph', 
          'name2': 'Bella',
          'name3': 'Aisha',
          'name4': 'Tom'
         }
print('Aisha' in family)  # default olarak key'e bakar ve False
print('Aisha' in family.values())  # values'lar içinde bak yazdim ve True
print('name3' in family)  # key'e bakar True
print('name11' not in family)  # not in ile sordum
# Out:
# False
# True
# True
# True

# %% [markdown]
# # Ic ice sözlükler = Nested dicts

# %%
school_records={
	'personal_info':
	   	{'kid':{'tom':{'class':'intermediate', 'age':10},
              'sue':{'class':'elemantary', 'age':8}
			       },
	    'teen':{'joseph':{'class':'college', 'age':19},
              'marry':{'class':'high school', 'age':16}
		         },
	  	},
}

print(school_records['personal_info']['teen']['marry']['age'])
                    # indis yerine keyleri [] icinde yazdik
# Out:
# 16

# %%
school_records={
	'personal_info':
		{'kid':{'tom':{'class':'intermediate', 'age':10},
			'sue':{'class':'elemantary', 'age':8}
			},
		'teen':{'joseph':{'class':'college', 'age':19},
			'marry':{'class':'high school', 'age':16}
			},
		},
	'grades_info':
		{'kid':{'tom':{'math':88, 'speech':69},
			'sue':{'math':90, 'speech':81}
			},
		'teen':{'joseph':{'coding':80, 'math':89},
			'marry':{'coding':70, 'math':96}
			},
		}
}  # josef'in sinav notlarini almak istiyorum
print(school_records['grades_info']['teen']['joseph'])  # items verdi
print(list(school_records['grades_info']['teen']['joseph'])) # key'leri verdi
print(list(school_records['grades_info']['teen']['joseph'].values())) # values
# Out:
# {'coding': 80, 'math': 89}
# ['coding', 'math']
# [80, 89]

# %%
friends = {
    'work_friend':{
    'friend1': {'first': 'Sue', 'last':'Bold'},
    'friend2': {'first': 'Steve', 'last':'Job'},
    'friend3': {'first': 'Bulend', 'last':'Hoca'}   
    },
   'family': {
    'family1': {'first': 'Aisha', 'last':'Dede'},
    'family2': {'first': 'Samuel', 'last':'Job'},
    'family3': {'first': 'Tom', 'last':'Bob'}   
   }
}
print (friends)
# Out:
# {'work_friend': {'friend1': {'first': 'Sue', 'last': 'Bold'}, 'friend2': {'first': 'Steve', 'last': 'Job'}, 'friend3': {'first': 'Bulend', 'last': 'Hoca'}}, 'family': {'family1': {'first': 'Aisha', 'last': 'Dede'}, 'family2': {'first': 'Samuel', 'last': 'Job'}, 'family3': {'first': 'Tom', 'last': 'Bob'}}}

# %% [markdown]
# *get sorgulama metodudur*

# %%
#Task: girilen rakamın harf karşılığını veren program
rakam = int(input("1-9 arası rakam giriniz..:"))
my_dict = {1:'bir', 2:'iki', 3:'üç', 4:'dört', 5:'beş', 6:'altı', 7:'yedi', 8:'sekiz', 9:'dokuz'}
# Girilen, sözlükte var mı? Varsa value, yoksa mesaj versin
print(my_dict.get(rakam, "sözlükte yoktur"))
# Out:
# 1-9 arası rakam giriniz..:111
# sözlükte yoktur

# %%
#Task: girilen rakamın harf karşılığını veren program
rakam = int(input("1-9 arası rakam giriniz..:"))
my_dict = {1:'bir', 2:'iki', 3:'üç', 4:'dört', 5:'beş', 6:'altı', 7:'yedi', 8:'sekiz', 9:'dokuz'}
# Girilen, sözlükte var mı? Varsa value, yoksa yazarsam mesaj verir yazmaysam none der
print(my_dict.get(rakam, "sözlükte yoktur"))
print(my_dict.get(rakam))
# Out:
# 1-9 arası rakam giriniz..:45
# sözlükte yoktur
# None

# %%
#Task:Türkçe-İngilizce sözlük
ara = input("Türkçe kelime giriniz..:")
## key:value(Türkçe:İngilizce)
trEn = {"pazartesi":"monday","salı":"tuesday", "çarşamba":"wednesday", "perşembe":"thursday",
        "cuma":"friday","cumartesi":"saturday","pazar":"sunday" }
print("English...: ", end=" ")  # end cikti formatini düzenler
# print("English...: ")  end kullanmayinca yanyana yazmayip alt satira yazar
print(trEn.get(ara, "sözlükte yoktur"))
# Out:
# Türkçe kelime giriniz..:salı
# English...:  tuesday
