# %%
print.__doc__  # __doc__ yazarak print komutunun neler yaptigini acıkladi
# Out:
# "print(value, ..., sep=' ', end='\\n', file=sys.stdout, flush=False)\n\nPrints the values to a stream, or to sys.stdout by default.\nOptional keyword arguments:\nfile:  a file-like object (stream); defaults to the current sys.stdout.\nsep:   string inserted between values, default a space.\nend:   string appended after the last value, default a newline.\nflush: whether to forcibly flush the stream."

# %%
import math 
math.__doc__  # math fonksiyonunun dokümantasyonunu istedim
# Out:
# 'This module provides access to the mathematical functions\ndefined by the C standard.'

# %%
# dir() : fonksiyonlarin/metotlarin ismini verir
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
#map()  : print(map.__doc__) bu sekilde map fonksiyonunun dokümantasyonunu alirim
#sum()  : ...
#input(): ...

# %%
uzun_kenar = 5  # Variable/ degisken atadik
text1 = "ali"
gun_adi = "Salı"
print(uzun_kenar, text1, gun_adi, sep="-")  # sep özelliği default olarak boşluk bırakırdi biz - koydurduk
# Out:
# 5-ali-Salı

# %% [markdown]
# Naming Yaklaşımları:
# **snake_case, CamelCase**, Pascal Case (pascalDili)

# %% [markdown]
# Snake Case örnekleri: uzun_kenar, ad_soyad
#
# Camel Case örnekleri: Class(Sınıf ismi) verirken StrDokuman
#
# ad_soyad = "Oguzhan"
#
# print ( type (ad_soyad ) )

# %%
ad_soyad = ""
# rakamla başlamayacak
# _ (underscore) karakteri haricinde özel karakter içermeyecek (^+&/-?*)
# O dile ait komutlar değişken ismi olarak kullanılamaz
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x = y = z = "same"
print(x)
print(y)
print(z)
# Out:
# same
# same
# same

# %%
x = y = z = "same" 
print(x, y, z)
# Out:
# same same same

# %%
x = y = z = "same "
print(x*3)
# Out:
# same same same

# %%
january = march = may = july = august = october = december = 31  
# multi assignments in a single line

april = june = september = november = 30

february = 28

print(january, february, march, april, may, june, july, august, september, october, november, december)
# Out:
# 31 28 31 30 31 30 31 31 30 31 30 31

# %%
# müdür müdür müdür?
print("müdür "*3, end="?")
# Out:
# müdür müdür müdür ?

# %%
# Değişkenimin alacağı değere ve tipine henüz karar vermediysem 'None'
volter = None
stringA = ""
intA = 0

# %%
first_number = 100
second_number = first_number
print(second_number)
# Out:
# 100

# %%
sayi1 = 5
sayi2 = 6
sayi2 = sayi1  # Eşitliğin sağ tarafı sol tarafa aktarılır.
# 5 = sayi1 hatalı durum
print(sayi2)
# Out:
# 5

# %%
a, b, c = 3, 5.2, "hello"
print(a)
print(b)
print(c)
# Out:
# 3
# 5.2
# hello

# %%
# Bu iki değişkenin içeriğini nasıl yer değiştiririz.
a, b = 3, 5
a, b = b, a # iki değişkenin içeriğini bilmiyoruz
print(a)
print(b)
# Out:
# 5
# 3

# %%
# Dairenin alanını hesaplayın
# Formül area = pi*r^2
# pi: sabit (constant)
# r: değişken
# area: değişken

PI = 3.14 # float (kesirli sayı)
r = 5     # int (tamsayı)
# PI = 4.5 Sabitlerin değeri değişmemesi Python 3.8 sonra gelen komut?
area = PI*r**2
print("Area..: ", area)
# Out:
# Area..:  78.5

# %%
my_text = """being a good person"""
print(my_text)
# Out:
# being a good person

# %%
my_text = 'being\na\ngood\nperson'
print(my_text)
# Out:
# being
# a
# good
# person

# %%
my_text = """being a good person"""
print(type(my_text))
no = 54
print(type(no))
# Out:
# <class 'str'>
# <class 'int'>

# %%
fish = """
  _
 /_|
('_)<|
 \_|
"""
print(type(fish))
print(fish)
# Out:
# <class 'str'>
#
#   _
#  /_|
# ('_)<|
#  \_|

# %%
email = "alfread@clarusway.com"
no = 632  # Normalde integer ama asagidaki gibi yazinca str oldu veya tirnak icine yazabilirdim
text1 = "It's early"
print(type(email), type(str(no)), type(text1))
# Out:
# <class 'str'> <class 'str'> <class 'str'>

# %%
sayi = -1
sayi2 = -1*2**10000 #Bilgisayarin islemcisine göre istedigin kadar yaz
print((sayi))
print((sayi2))
# Out:
# -1
# -...

# %%
sayi = 3.14
sayi2 = -1*int(sayi)*2**1000000
print(type(sayi))
print(type(sayi2))  # Negatif de olsa pozitif de olsa sayi tipi ayni
# Out:
# <class 'float'>
# <class 'int'>

# %%
print(bool(0))  # Eger bir verimiz 0 ya da None degilse True'dur
print(bool(5))
print(bool(None))
print(bool(3) + bool(5))  # Boolen sonucu ya evettir ya hayir. Ya 1 ya 0
# Out:
# False
# True
# False
# 2

# %%
number_int = 123
number_str = "456"
print(number_str + str(number_int))
# Out:
# 456123

# %%
number_int = 123
number_str = "456"
print(int(number_str) + (number_int))
# Out:
# 579

# %%
"""
print(int("5" + "1")) # int("51") : 51
print("3" + str("5" + "1"))  # 351
print(3 + int("5" + "1"))  # 3 + 51 = 54
print(str(3) + ("5" + "1"))  # 351
print(type(float(3) + int("5" + "1"))) # <class 'float'>

print(int(False) + bool("volkan"))  # 1
print(bool(int(False) + bool("volkan")))  # True
"""
print(bool(1))
print(bool(''))  # None
print(bool(""))  # None algılar
print(bool(0))
# Out:
# True
# False
# False
# False
