# %%
import earth.europe.kosovo  # importing with naming package, subpackage and module

earth.europe.kosovo.a_function()  # we want to access a function defined in kosovo module

# %%
from earth import europe.kosovo  # importing with naming subpackage and module

europe.kosovo.a_function()  # we want to access a function defined in kosovo module

# %%
from earth.europe import kosovo  # importing without naming package and subpackage

kosovo.a_function()  # we want to access a function defined in kosovo module

# %%
from earth.europe.kosovo import a_function()  # importing without any naming 

a_function()  # we use directly the function's name

# %% [markdown]
# # PIP

# %%
pip --version
# Out:
# pip 21.2.4 from C:\Users\uksal\AppData\Local\Programs\Python\Python310\lib\site-packages\pip (python 3.10)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
##colab için
# %pip install text-to-speech
##python -m pip install ... (windows için)

# %%
from text_to_speech import speak
def text(st):
    return "Merhaba" + st

speak(text("Ahmet"), "tr", save=True, file="HelloWorld.mp3", speak=True)

# %%
from text_to_speech import speak
def text(st):
    return "Merhaba" + st

speak(text("Ahmet"), "tr")

# %%
# %pip install pandas

# %%
pip list

# %%
pip show text_to_speech

# %%
# %pip show pandas

# %%
pip install pandas

# %%
pip install covid
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for covid: filename=covid-2.5.2-py3-none-any.whl size=10401 sha256=249e8eb9fcc937c365866063d81b576c8d5e261e60b774ab05a7b259acd81a34
#   Stored in directory: c:\users\uksal\appdata\local\pip\cache\wheels\e3\c4\ec\97ad7ec9dc18a080f21d23ca7e5ea80c45ccdd2657ad713dd4
# Successfully built covid
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script covid.exe is installed in 'C:\Users\uksal\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
from covid import Covid

covid = Covid()
covid.get_data()
# Out:
# [{'id': '184',
#   'country': 'US',
#   'confirmed': 80399474,
#   'active': None,
#   'deaths': 985482,
#   'recovered': None,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'last_update': 1649553657000},
#  {'id': '81',
#   'country': 'India',
#   'confirmed': 43034217,
#   'active': None,
#   'deaths': 521656,
#   'recovered': None,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'last_update': 1649553657000},
#  {'id': '25',
#   'country': 'Brazil',
#   'confirmed': 30146769,
#   'active': None,
#   'deaths': 661475,
#   'recovered': None,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'last_update': 1649553657000},
#  {'id': '64',
#   'country': 'France',
#   'confirmed': 27029180,
#   'active': None,
#   'deaths': 144280,
#   'recovered': None,
#   'latitude': 46.2276,
#   'longitude': 2.2137,
#   'last_update': 1649553657000},
#  {'id': '68',
#   'country': 'Germany',
#   'confirmed': 22629378,
#   'active': None,
#   'deaths': 131679,
# ...

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: seaborn in c:\users\uksal\appdata\local\programs\python\python310\lib\site-packages (0.11.2)
# ...
#
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\uksal\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
#pip install seaborn
from covid import Covid
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
covid = Covid()
df = pd.DataFrame(covid.get_data())
top10 = df.head(10)
print(top10)
deaths = top10.deaths
countries = top10.country
sns.barplot(countries, deaths, data=top10 )
plt.title("Vefat sayilari")
plt.show()
# Out:
#     id         country  confirmed active  deaths recovered   latitude  \
# 0  184              US   80399474   None  985482      None  40.000000
# 1   81           India   43034217   None  521656      None  20.593684
# 2   25          Brazil   30146769   None  661475      None -14.235000
# 3   64          France   27029180   None  144280      None  46.227600
# 4   68         Germany   22629378   None  131679      None  51.165691
# 5  188  United Kingdom   21716180   None  170367      None  55.000000
# 6  146          Russia   17720977   None  364011      None  61.524000
# 7   94    Korea, South   15333670   None   19421      None  35.907757
# 8   87           Italy   15238128   None  160658      None  41.871900
# 9  183          Turkey   14953365   None   98377      None  38.963700
#
#     longitude    last_update
# 0 -100.000000  1649553657000
# 1   78.962880  1649553657000
# 2  -51.925300  1649553657000
# 3    2.213700  1649553657000
# 4   10.451526  1649553657000
# ...

# %% [markdown]
# Kaynak kod .py/ .ipynb gibi script veya modüllerden olusur. Bunlar yorumlayicidan(interpreter) gecerek
# .pyc uzantili bytecode olusur. bytecode bir editöre yüklendiginde sanal makinesi kurulmus olur. bytecode sanal makinenin yüklü oldugu her ortamda calisir.

# %%
# password generator by @hmet
import random
import string as st
# random.seed(1) ile hep ayni sifre olusur
l_case = st.ascii_lowercase
u_case = st.ascii_uppercase
numbers = st.digits
special_char = st.punctuation
all_char= l_case+u_case+numbers+special_char
password=''

for i in range(6):
    password += random.choice(all_char)

password += random.choice(l_case)
password += random.choice(u_case)
password += random.choice(numbers)
password += random.choice(special_char) 
password = ''.join(random.sample(password, 10)) 
print('Here is new generated password:')   
print(password)
# Out:
# Here is new generated password:
# 8))M6a[:~I

# %%
#Hatalar:
#1. Syntax (Yazım kuralı) hatası: editörler yardımcı oluyor
print("ali"
# Out:
#   Input In [22]
#     print("ali"
#          ^
# SyntaxError: '(' was never closed

# %%
print("ali')
# Out:
#   Input In [21]
#     print("ali')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
prit("ali")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\uksal\Desktop\PYTHON\Meine_Dokumente\Tag_19.ipynb Cell 23' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/uksal/Desktop/PYTHON/Meine_Dokumente/Tag_19.ipynb#ch0000023?line=0'>1</a> prit("ali")
#
# NameError: name 'prit' is not defined

# %%
x = 0
if x==5:
print("x":x)  # girinti hatasi
# Out:
#   Input In [25]
#     print("x":x)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
#Hatalar:
#2. Mantık (logic) hatası: tespiti zor: hata yok ama istenen çıktıyı vermiyor
#2-5 (toplama yerine çıkarma gibi)

# %%
#çalışma zamanı hatası (Exception-istisna)
