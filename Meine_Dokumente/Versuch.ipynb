# %%
print('i', end=' ')
print('will say', end=' ')
print("'i missed you'", end=' ')
print('to my mother')  # # Fark ettiyseniz, bu örnekte, kullanmasaydık normalde 4 satır 👉🏻 çıktı alırdık.end=end=' '
# Out:
# i will say 'i missed you' to my mother

# %%
print('i')
print('will say'
)
print("'i missed you'", end=' ')
print('to my mother')  # If you noticed, in the example above we have combined all expressions with 
                       # space in a single line using the 👉🏻 If we didn't use ,
                       # we would normally get 4 lines of output.end=end=' '
# Out:
# i
# will say
# 'i missed you' to my mother

# %%
x = 5
print ('value of x       : ', x)

x += 2
print ("2 more of x      : ", x, "\n")
# Out:
# value of x       :  5
# 2 more of x      :  7

# %%
x = 5
print ('value of x       : ', x)

x += 2
print ("2 more of x      : ", x)
# Out:
# value of x       :  5
# 2 more of x      :  7

# %%
print("one", "two", "three")
print("one", "two", "three", sep="\t")
# Out:
# one two three
# one	two	three

# %%
print('we', '\bare', '\bunited')
print('we', 'are', 'united')
# Out:
# united
# we are united

# %%
print("{9} {1} {10} {3} {2} {5} {8} {6} {0} {4}".format('in', 'know', 'bring', 'to', 'students.', 'out', 'best', 'teachers', 'the', 'Good', 'how'))
  #  "Good teachers know how to bring out the best in students."
# Out:
# Good know how to bring out the best in students.

# %%
print("{9} {1} {10} {3} {2} {5} {8} {6} {0} {4}".format('in', 'know', 
'bring', 'to', 'students.', 'out', 'best', 'teachers', 'the', 'Good', 'how'))
  #  "Good teachers know how to bring out the best in students."
# Out:
# Good know how to bring out the best in students.

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = (f"Hi {name}. " 
           f"You are one of the {job} "
     f"in the {domain} section.")
print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section.

# %%
name = "Joseph"
job = "teachers"
domain = "Data Science"
message = f"Hi {name}. " \
     f"You are one of the {job} " \
     f"in the {domain} section."

print(message)
# Out:
# Hi Joseph. You are one of the teachers in the Data Science section.

# %%
phrase = "myemailaddress@clarusway.com"

print(len(phrase))
print(phrase.startswith("@", 14))
print(phrase.endswith(".", 15, 24))
# Out:
# 28
# True
# False

# %%
print("{4} {9} {1} {7} {5} {0} {6} {8} {3} {2}".format('while', 'dream', 'work.', 'and', 'Some', 'success', 'others', 'of', 'wake up', 'people'))
# Out:
# Some people dream of success while others wake up and work.

# %%
print(int("5" + "1"))
print(str("5" + "1"))
print("5" + "1")
# Out:
# 51
# 51
# 51

# %%
city = "SARAJEVO"
print(f"I live in {city.capitalize()}.")

city = "SARAJEVO"
text = f"{I live in {city}.capitalize()}"
print(text)
# Out:
#   Input In [17]
#     text = f"{I live in {city}.capitalize()}"
#      ^
# SyntaxError: f-string: invalid syntax. Perhaps you forgot a comma?

# %%
print({0} and False or [])
# Out:
# []

# %%
print("I'm Oguzhan")
# print('I'm Oguzhan') basladigimla bitirdim ama arada aynisindan var. Bu yüzden hata verir.
# '...' veya '''...''' olur ama ''...'' olmaz. Iki tek tirnak cift tirnaga benziyor hata veriyor.

# %%
print('Eyyup\tOguzhan\t\tUksal') # \t bir tab bosluk birak yani genellikle 4 space demek
# Out:
# Eyyup	Oguzhan		Uksal

# %%
print('C:\\north pole\noise_penguins.txt')  # iki \ olunca birini aldi 
print('---------')
print('first', 'second', 'third', sep='\t')
# Out:
# C:\north pole
# oise_penguins.txt
# ---------
# first	second	third

# %%
print(r'ab\'c')
# Out:
# ab\'c

# %%
#Kullanicidan alinan 2 sayinin toplami
a = float(input("Bir sayi giriniz: " ))
b= float(input("Bir sayi giriniz: " ))
print("iki sayinin toplami:", a+b)

# 1. kullanici 3 ve 5 girerek 8 görmek istiyor
# 2. kullanici uc ve bes girerek sekizi görmek istiyor
# 3. kullanici 3.5 ve 5.5 girerek 9 veya 9.0 görmek istiyor
# 4. kullanici 3,5 ve 5,5 girerek 9 veya 9,0 görmek istiyor
# Out:
# iki sayinin toplami: 8.0

# %%
print(int(3.5))
print(int("3.5"))  # "3.5" integer degil ve hata verdi
# Out:
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\uksal\Desktop\Meine_Dokumente\Versuch.ipynb Cell 22' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/uksal/Desktop/Meine_Dokumente/Versuch.ipynb#ch0000022?line=0'>1</a> print(int(3.5))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/uksal/Desktop/Meine_Dokumente/Versuch.ipynb#ch0000022?line=1'>2</a> print(int("3.5"))
#
# ValueError: invalid literal for int() with base 10: '3.5'

# %%
num = int(input("You entered number..:"))
print(num, num % 2 == 0 and "even" or "odd")  # cift sayi mi degil mi
# Out:
# 11 odd

# %%
age = input("age")
print(age.isdigit())
# Out:
# False

# %%
# Tek tek bulmasin. herhangi bir sayiya bölündügünde döngüden ciksin
# Asal mı? 
n = int(input("Sayı..:"))
print(n)
flag = True  # Bayrak değişkeni amacı: girilen sayının asal old. kabul ediliyor
for x in range(2,n):  # kareköke kadar giderek arattirmak cözümü hizlandirir
    if n % x == 0:    # kendinden önceki sayilara tam bölünüyorsa False
        flag = False  # Bayrak durumu degisti, Asal değil

if flag == False or n == 1:
    print("Asal Değil")
else:
    print("Asal")

# %%
a = ["1", "2", "3", "4", "5"]
while a: 
    if len(a) < 3:
        break
    print(a.pop())
print("Done.")

# %%
def Fizz_Buzz(a):
    for a in range(1,101):
        if a % 3 == 0 :
            print(a: , "fizz")
        elif a % 5 == 0 :
            print(a: , "buzz")
        elif (a % 3 == 0 and numbers % 5 == 0)  :
            print(a: , "FizzBuzz")
        else:
            print(a)
# Out:
#   Input In [12]
#     print(a: , "fizz")
#            ^
# SyntaxError: invalid syntax

# %%
def texter(a,b,c):  # positional args.
    print(b,c,a)    # istenen sonuc icin c- a oldu, a- b oldu, b- c oldu...

# ana program
a = 'i'
b = 'love'
c = 'you'
texter(c,a,b)  # bu sirayla bassin istiyorum

# %%
if n == False:
        return False
    else:
        return True  


    liste_1 = [] # boş liste
    dict_2 = {True, 1, True, 1, 0} # sadece bir tane değerin false olduğu durum
    liste_3 = [1, False, 0] # sadece bir tane değerin True olduğu liste
    liste_4 = [False,  0, False, 0] # tüm değerlerin false olduğu liste
# Out:
#   File <tokenize>:3
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# any() fonksiyonu 
my_any = []  # boş liste
my_any = {True, 1, True, 1, 0} # sadece bir tane değerin false olduğu durum
my_any = [1, False, 0] # sadece bir tane değerin True olduğu liste
my_any = [False,  0, False, 0] # tüm değerlerin false olduğu liste
def my_any():
    input()
    list
    if my_any == True
    else my_any == False
        print(type(my_any))
    """
    list, tuple yada dict gibi iterable fonksiyonlarin herhangi bir elemaninin boolen degeri True ise True döndürür.

    iterable boş ise veya hepsinin boolen degeri False ise False döndürür.
    """ 

# fonksiyonu çağıralım

print(any(my_any))
print(any(my_any))
print(my_any.__doc__)  # Python __doc__ ile o foksiyonun ne yaptigini veriyordu. def ile bunu da tanimladim
# Out:
#   Input In [29]
#     if my_any == True
#                      ^
# SyntaxError: expected ':'

# %%
def my_any():
    if my_any == True:
        print("True")
    else:
        print("False")
        
my_any1 = [1, False, 0] 
my_any(my_any1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 8>()
#       5         print("False")
#       7 my_any1 = [1, False, 0]
# ----> 8 my_any(my_any1)
#
# TypeError: my_any() takes 0 positional arguments but 1 was given

# %%
def my_any(list1):
    """
    list, tuple yada dict gibi iterable fonksiyonlarin herhangi bir elemaninin boolen degeri True ise True döndürür.

    iterable boş ise veya hepsinin boolen degeri False ise False döndürür.
    """ 
    for i in list1:
        if i:
            return True
    return False
    
list_a = [1, False, 0]  # sadece bir tane değerin True olduğu liste
list_b = [False,  0, False, 0] # tüm değerlerin false olduğu liste
list_c = []  # boş liste
list_d = {True, 1, True, 1, 0} # sadece bir tane değerin false olduğu durum
my_any(list_b)
# Out:
# False

# %%
cümle=tuple()
cümle=input("Bir cümle giriniz: ")
print(cümle) 
print(len(cümle))
# Out:
# ()
# 0

# %%
cümle = input("bir cumle yaziniz")
a = dict()
for i in cümle:
    a.update({i:cümle.count(i)})

print(cümle)
print(len(cümle))  
print(a)
# Out:
# Pertevniyalli olmak ayricaliktir! En büyük Fenerbahce!
# 54
# {'P': 1, 'e': 5, 'r': 4, 't': 2, 'v': 1, 'n': 3, 'i': 5, 'y': 3, 'a': 5, 'l': 4, ' ': 5, 'o': 1, 'm': 1, 'k': 3, 'c': 2, '!': 2, 'E': 1, 'b': 2, 'ü': 2, 'F': 1, 'h': 1}

# %%
family_members = ['Meghan', 'Tom', 'Nicole', 'Tim']
neu = tuple(family_members)
print(list(neu))
# Out:
# ['Meghan', 'Tom', 'Nicole', 'Tim']

# %%
def printMax(a, b):
 if a > b:
    print(a, 'is maximum')
 elif a == b:
    print(a, 'is equal to', b)
 else:
    print(b, 'is maximum')
printMax(3, 4)
# Out:
# 4 is maximum

# %%
x = 50
def func(x):
 print('x is', x)
 x = 2
 print('Changed local x to', x)
func(x)
print('x is now', x)
# Out:
# x is 50
# Changed local x to 2
# x is now 50

# %%
def function1(var1=5, var2=7):
 var2=9
 var1=3
 print (var1, " ", var2)
function1(10,12)
# Out:
# 3   9

# %%
import cmath
print(cmath.sqrt(4))
# Out:
# (2+0j)

# %%
iterable = [1, 2, 3, 4]
a=1
for i in iterable:
    try:
        a=i**2
        print(a)
        i += i
    except:
        print("hata var")
# Out:
# 1
# 4
# 9
# 16

# %%
# Write a program that prints square of each number of the iterable list below each on separate lines.
# Note: Use for loop with power (**) or multiplying (*) syntaxes.

iterable = [1, 2, 3, 4]
a=1
for i in iterable:
        a = i**2
        print(a)
        i += i
# Out:
# 1
# 4
# 9
# 16

# %%
iterable = [1, 2, 3, 4]
for i in iterable:
        print(i**2)
# Out:
# 1
# 4
# 9
# 16

# %%
n = int(input('enter a number between 1-10'))

for i in range(11):
    print('{}x{} = '.format(n, i), n*i)
# Out:
# 3x0 =  0
# 3x1 =  3
# 3x2 =  6
# 3x3 =  9
# 3x4 =  12
# 3x5 =  15
# 3x6 =  18
# 3x7 =  21
# 3x8 =  24
# 3x9 =  27
# 3x10 =  30

# %%
a = 3
while a**2 < 299:
    print('I will stop smoking')
    print(a)
    a += 3
# Out:
# I will stop smoking
# 3
# I will stop smoking
# 6
# I will stop smoking
# 9
# I will stop smoking
# 12
# I will stop smoking
# 15

# %%
math_mark = int(input('Please enter the mark: '))

if 85 <= math_mark <= 100:
    print('A (Excellent)')
elif 70 <= math_mark <= 84:
    print('B (Good)')
elif 60 <= math_mark <= 69:
    print('C (Medium)')
elif 45 <= math_mark <= 59:
    print('D (Not Bad)')
else:
    0 <= math_mark <= 44
    print('F (Failed)')
# Out:
# A (Excellent)

# %%
score = int (input("Enter your score :"))

if score >= 90:
    if score >= 95:
        Score_letter="A+"
    else:
        Score_letter="A"
elif score >= 80:
    if score >= 85:
        Score_letter="B+"
    else:
        Score_letter="B"
else:
    Score_letter="below B"

print ("Your degree: %s" % Score_letter)
# Out:
# Your degree: below B

# %%
saved_amount = int(input('Please enter your saved amount: '))
if saved_amount <= ps4_price/2:
    print('You must save more, keep saving!')
elif saved_amount > ps4_price/2 and saved_amount < ps4_price:
    print('You saved more than half, keep saving!')
else:
    print('Yippee! You can buy your PS4')

# %%
n=int(input('Enter a number to check if it is a prime number : '))
count=0
for i in range(1, n+1):
    if n%i==0 : count += 1
    else : count += 0
if count < 3: print(f'{n} is a prime number')
else : print(f'{n} is not a prime number')
# Out:
# 7 is a prime number

# %%
def longer(a, b):
    if len(a) >= len(b):
        return a
    else:
        return b

print(longer('Richard', 'John'))
# Out:
# Richard

# %%
def make_sentence(**kwargs):
    result = ""
    # Iterating over the Python kwargs dictionary
    for i in kwargs.values():
        result += i
    return result

print(make_sentence(a="I ", b="love ", c="Clarusway!"))
# Out:
# I love Clarusway!

# %%
text = "I am the global one"
 
def global_func():
    print(text)  # we can use 'text' in a function
                 # because it's a global variable

global_func()  # 'I am the global one' will be printed
print(text)  # it can also be printed outside of the function

text = "The globals are valid everywhere "
 
global_func()  # we changed the value of 'text'
# 'The globals are valid everywhere' will be printed
 
def local_func():
    text = "I am the local one"
    print(text)  # local_text is a local variable

local_func()  # 'I am the local one' will be printed as expected
 
print(text)  # NameError will be raised
# because we can't use local variable outside of its function
# Out:
# I am the global one
# I am the global one
# The globals are valid everywhere
# I am the local one
# The globals are valid everywhere

# %%
def outer():
    x = "previous"
    
    def inner():
        global outer
        x = "later"
        print("inner:", x)
    
    inner()
    print("outer:", x)
    
print("outer:", x)
# Out:
# outer: My name is Richard

# %%
x = 'My name is Richard'
def my_function_1(): 
    x = 'My name is John'
    
print(x)
# Out:
# My name is Richard

# %%
city = "I love Paris!"

def my_function(): 
    city = "I love London!"

    print(city) 
my_function()
# Out:
# I love London!

# %%
def outer():
    x = "previous"
    
    def inner():
        nonlocal x
        x = "later"
        print("inner:", x)
    
    inner()
    print("outer:", x)
