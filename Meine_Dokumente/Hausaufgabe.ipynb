# %%
#Task: Wörter mit „synonym“ 
suchen = input("Bitte schreiben Sie ein deutsches Wort:")
SynDe = {"bieten":"offerieren","anfangen":"beginnen", "Auto":"Wagen",
        "Karotten":"Moehren","anrufen":"telefonieren","einfach":"leicht", 
         "helfen":"unterstützen", "Pilze":"Champignons", "See":"Meer", "Orange":"Apfelsine" }
print("synonym...: ", end=" ") 
print(SynDe.get(suchen, "leider nicht gefunden"))
# Out:
# Bitte schreiben Sie ein deutsches Wort:bieten
# synonym...:  offerieren

# %%
"""
    list, tuple yada dict gibi iterable fonksiyonlarin herhangi bir elemaninin boolen degeri True ise True döndürür.

    iterable boş ise veya hepsinin boolen degeri False ise False döndürür.
""" 
def my_any(list1):

    for i in list1:
        if i:
            return True
    return False
    
list_a = [1, False, 0]  # sadece bir tane değerin True olduğu liste
list_b = [False,  0, False, 0] # tüm değerlerin false olduğu liste
list_c = []  # boş liste
list_d = {True, 1, True, 1, 0} # sadece bir tane değerin false olduğu durum
my_any(list_b)
